# %% [markdown]
# # Spotify Clone
#
# Proyek fullstack Spotify Clone dengan:
# - **Backend**: Python FastAPI + yt-dlp (YouTube search & audio extraction)
# - **Frontend**: React + Vite + Three.js (3D visualizer, particle field, vinyl disc)
# - **Database**: SQLite (favorites, playlists)
#
# Clone dari: https://github.com/andjanuardi/spotify-clone

# %% [markdown]
# ---
# ## 1. Install System Dependencies

# %%
# Install ffmpeg (diperlukan oleh yt-dlp untuk processing audio)
# !apt-get update && apt-get install -y ffmpeg

# %% [markdown]
# ---
# ## 2. Install / Cek Node.js

# %%
# Install Node.js 20.x jika belum ada
# !which node || (curl -fsSL https://deb.nodesource.com/setup_20.x | bash - && apt-get install -y nodejs)
# !node --version && npm --version

# %% [markdown]
# ---
# ## 3. Clone Repository

# %%
# !git clone https://github.com/andjanuardi/spotify-clone.git
# %cd spotify-clone

# %% [markdown]
# ---
# ## 4. Install Python Dependencies

# %%
# !pip install -r backend/requirements.txt

# %% [markdown]
# ---
# ## 5. Build Frontend

# %%
# %cd frontend
# !npm install
# !npm run build
# %cd ..

# %% [markdown]
# ---
# ## 6. Jalankan Backend Server

# %%
import subprocess
import time
import os

os.chdir('/content/spotify-clone/backend')

proc = subprocess.Popen(
    ['python', 'main.py'],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
)

time.sleep(3)
print('Backend server berjalan di port 8000')

# %% [markdown]
# ---
# ## 7. Buka Aplikasi

# %%
from google.colab import output
output.serve_kernel_port_as_window(8000)
print('Klik link di atas untuk membuka Spotify Clone!')
